# %% [markdown]
# # import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
import datetime
from sklearn.metrics import mean_squared_error,mean_absolute_error,root_mean_squared_error,r2_score

# %% [markdown]
# # load data

# %%
data=pd.read_csv("carprice_ml_pro.csv")
df=pd.DataFrame(data)
df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 8364   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  Cargo Volumn  \
# 0            Maruti         Maruti Celerio       2015  ...    235-litres
# 1              Ford          Ford Ecosport       2018  ...    352-litres
# 2              Tata             Tata Tiago       2018  ...    242-litres
# 3           Hyundai          Hyundai Xcent       2014  ...    407-litres
# 4            Maruti     Maruti SX4 S Cross       2015  ...    353-litres
# ...             ...                    ...        ...  ...           ...
# 8364         Maruti         Maruti Celerio       2022  ...           313
# 8365         Maruti        Maruti Alto 800       2014  ...    177-litres
# 8366  Mercedes-Benz  Mercedes-Benz C-Class       2011  ...    475-litres
# 8367         Maruti            Maruti Ritz       2012  ...    236-liters
# 8368        Renault         Renault Duster       2017  ...    410-litres
#
#      Alloy Wheel Size_2       City Gear Box_1  Rear Brake Type_1  \
# 0                   NaN  Bangalore        NaN                NaN
# 1                    16  Bangalore        NaN                NaN
# 2                    14  Bangalore        NaN                NaN
# 3                    14  Bangalore        NaN                NaN
# 4                    16  Bangalore        NaN                NaN
# ...                 ...        ...        ...                ...
# 8364                NaN    Kolkata        NaN                NaN
# 8365                NaN    Kolkata        NaN                NaN
# 8366                NaN    Kolkata        NaN                NaN
# 8367                NaN    Kolkata        NaN                NaN
# 8368                NaN    Kolkata        NaN                NaN
#
#       Front Brake Type_1 Acceleration_1 Top Speed_1 Drive Type_1  \
# 0                    NaN            NaN         NaN          NaN
# 1                    NaN            NaN         NaN          NaN
# 2                    NaN            NaN         NaN          NaN
# 3                    NaN            NaN         NaN          NaN
# 4                    NaN            NaN         NaN          NaN
# ...                  ...            ...         ...          ...
# 8364                 NaN            NaN         NaN          NaN
# 8365                 NaN            NaN         NaN          NaN
# 8366                 NaN            NaN         NaN          NaN
# 8367                 NaN            NaN         NaN          NaN
# 8368                 NaN            NaN         NaN          NaN
#
#      Turning Radius_1
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 8364              NaN
# 8365              NaN
# 8366              NaN
# 8367              NaN
# 8368              NaN
#
# [8369 rows x 88 columns]

# %% [markdown]
# # new features finding

# %%
current_year=datetime.datetime.now().year
current_year
# Out:
# 2025

# %%
df["Car Age"]=current_year-df["modelYear"]
df["Car Age"]
# Out:
# 0       10
# 1        7
# 2        7
# 3       11
# 4       10
#         ..
# 8364     3
# 8365    11
# 8366    14
# 8367    13
# 8368     8
# Name: Car Age, Length: 8369, dtype: int64

# %%
df["Length"]=df["Length"].str.replace("mm","").str.replace(",","").str.strip().astype(float)
df["Width"]=df["Width"].str.replace("mm","").str.replace(",","").str.strip().astype(float)
df["Height"]=df["Height"].str.replace("mm","").str.replace(",","").str.replace("-","").str.strip().astype(float)

# %%
df["Car Size"]=df["Length"]*df["Width"]*df["Height"]
df["Car Size"].unique()
# Out:
# array([9.50584912e+09, 1.16220061e+10, 9.47043117e+09, 1.00801840e+10,
#        1.22424225e+10, 1.31037804e+10, 9.22082775e+09, 1.13491958e+10,
#        1.15350345e+10, 1.05266252e+10, 9.49984800e+09, 1.03444449e+10,
#        1.54681852e+10, 1.44357199e+10, 1.02813322e+10, 1.16135047e+10,
#        1.12510710e+10, 1.31187614e+10, 1.02067448e+10, 1.34649444e+10,
#        1.66939261e+10, 9.26398200e+09, 8.64423375e+09, 1.40692669e+10,
#        1.36849871e+10, 1.31335956e+10, 9.14685850e+09, 1.28867992e+10,
#        1.36495682e+10, 1.53841102e+10, 1.59817800e+10, 1.03995350e+10,
#        1.18199025e+10, 1.34506631e+10, 7.69828312e+09, 1.58973872e+10,
#        9.40161530e+09, 1.27767150e+10, 1.56674131e+10, 7.52648250e+09,
#        2.02795520e+10, 1.57666901e+10, 1.92437940e+10, 8.68370103e+09,
#        1.16236463e+10, 9.61062975e+09, 9.50917488e+09, 1.09243593e+10,
#        1.23889780e+10, 1.48568921e+10, 1.01934720e+10, 1.32979542e+10,
#        1.33655686e+10, 1.25037569e+10, 1.02740400e+10, 1.06721431e+10,
#        1.11758130e+10, 9.70246562e+09, 1.09916091e+10, 1.04308444e+10,
#        1.68701199e+10, 8.95637700e+09, 8.86301625e+09, 8.58591040e+09,
#        1.44238790e+10, 1.18362542e+10, 1.52437120e+10, 9.09720000e+09,
#        7.79567000e+09, 1.12097212e+10, 8.12587500e+09, 1.09417809e+10,
#        1.14445988e+10, 1.50337880e+10, 1.34921250e+10, 1.26549990e+10,
#        1.25845950e+10, 1.21146892e+10, 1.16988472e+10, 1.30277374e+10,
#        1.33259714e+10, 1.60038186e+10, 7.99474400e+09, 1.01397870e+10,
#        1.67150834e+10, 1.00448242e+10, 9.97353500e+09, 1.14029934e+10,
#        1.66844978e+10, 1.16704456e+10, 1.37427250e+10, 1.63218204e+10,
#        1.13232210e+10, 1.44229378e+10, 1.44742020e+10, 9.81177712e+09,
#        1.39885200e+10, 1.31030852e+10, 1.42024960e+10, 1.55010240e+10,
#        1.48925801e+10, 1.27616236e+10, 1.17277220e+10, 1.05009574e+10,
#        1.21811599e+10, 1.20554654e+10, 1.09193779e+10, 1.17306456e+10,
#        1.09335160e+10, 1.31102302e+10, 1.11017599e+10, 1.66234800e+10,
# %% [markdown]
# # drop unwanted columns

# %%
new_df=df.drop(columns=['it', 'owner',  'centralVariantId', 'variantName',
       'priceActual', 'priceSaving', 'priceFixedText', 'trendingText.imgUrl',
       'trendingText.heading', 'trendingText.desc', 'Registration Year',
       'Fuel Type', 'Kms Driven', 'RTO',
       'Ownership', 'Engine Displacement', 'Transmission',
       'Year of Manufacture', 'Max Power', 'Torque',
       'Seats_1', 'Wheel Size', 'Engine Type', 'Displacement',
       'Max Power_1', 'Max Torque', 'No of Cylinder', 'Values per Cylinder',
       'Value Configuration', 'Fuel Suppy System', 'BoreX Stroke',
       'Compression Ratio', 'Turbo Charger', 'Super Charger',
       'Seating Capacity', 'Steering Type', 'Tyre Type', 'Alloy Wheel Size',
       'No Door Numbers', 'Length', 'Width', 'Height', 'Wheel Base',
       'Front Tread', 'Rear Tread', 'Kerb Weight', 'Gross Weight',
       'Ground Clearance Unladen', 'Seating Capacity_1', 'Steering Type_1',
       'Tyre Type_1', 'Alloy Wheel Size_1', 'No Door Numbers_1', 'Gear Box',
       'Drive Type', 'Seating Capacity_2', 'Steering Type_2', 'Turning Radius',
       'Front Brake Type', 'Rear Brake Type', 'Top Speed', 'Acceleration',
       'Tyre Type_2', 'No Door Numbers_2', 'Cargo Volumn',
       'Alloy Wheel Size_2', 'Gear Box_1', 'Rear Brake Type_1',
       'Front Brake Type_1', 'Acceleration_1', 'Top Speed_1', 'Drive Type_1',
       'Turning Radius_1'],inplace=True)
new_df

# %% [markdown]
# # remove string spaces in numerical columns

# %%
df["km"]=df["km"].str.replace(",","").str.strip().astype(float)
df["Insurance Validity"]=df["Insurance Validity"].str.replace("2","Second Party").str.replace("1","First Party").str.strip()
df["Seats"]=df["Seats"].str.replace("Seats","").str.strip().astype(float)
df["Mileage"]=df["Mileage"].str.replace("kmpl","").str.replace("km/kg",'').str.strip().astype(float)
df["Engine"]=df["Engine"].str.replace("CC","").str.strip().astype(float)
df["price"]=df["price"].str.replace("Lakh","").str.replace("Crore","").str.replace(",","").str.replace("₹","").str.strip().astype(float)

# %% [markdown]
# # drop duplicate values

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna(subset=["Mileage"],inplace=True)
df.shape
# Out:
# (7975, 17)

# %% [markdown]
# # drop null vales presented rows

# %%
df.dropna(subset=["Car Size"],inplace=True)
df.shape
# Out:
# (7915, 17)

# %% [markdown]
# # fill missing values

# %%
df["bt"].fillna(df["bt"].mode()[0],inplace=True)
df["Insurance Validity"].fillna(df["Insurance Validity"].mode()[0],inplace=True)
df["Seats"].fillna(df["Seats"].median(),inplace=True)
df["Engine"].fillna(df["Engine"].mode()[0],inplace=True)
df["Color"].fillna(df["Color"].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7915 entries, 0 to 8368
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ft                  7915 non-null   object
#  1   bt                  7915 non-null   object
#  2   km                  7915 non-null   float64
#  3   transmission        7915 non-null   object
#  4   ownerNo             7915 non-null   int64
#  5   oem                 7915 non-null   object
#  6   model               7915 non-null   object
#  7   modelYear           7915 non-null   int64
#  8   price               7915 non-null   float64
#  9   Insurance Validity  7915 non-null   object
#  10  Seats               7915 non-null   float64
#  11  Mileage             7915 non-null   float64
#  12  Engine              7915 non-null   float64
#  13  Color               7915 non-null   object
#  14  City                7915 non-null   object
#  15  Car Age             7915 non-null   int64
#  16  Car Size            7915 non-null   float64
# dtypes: float64(6), int64(3), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# # handle outliers

# %%
q1=df["price"].quantile(0.25)
q3=df["price"].quantile(0.75)
iqr=q3-q1
lf=q1-1.5*iqr
uf=q3+1.5*iqr
dff=df[(df["price"]>lf)&(df['price']<uf)]
dff
# Out:
#           ft         bt        km transmission  ownerNo            oem  \
# 0     Petrol  Hatchback  120000.0       Manual        3         Maruti
# 1     Petrol        SUV   32706.0       Manual        2           Ford
# 2     Petrol  Hatchback   11949.0       Manual        1           Tata
# 3     Petrol      Sedan   17794.0       Manual        1        Hyundai
# 4     Diesel        SUV   60000.0       Manual        1         Maruti
# ...      ...        ...       ...          ...      ...            ...
# 8364  Petrol  Hatchback   10000.0       Manual        1         Maruti
# 8365  Petrol  Hatchback  120000.0       Manual        1         Maruti
# 8366  Petrol      Sedan   50000.0    Automatic        3  Mercedes-Benz
# 8367  Petrol  Hatchback   40000.0       Manual        1         Maruti
# 8368  Diesel        SUV  120000.0       Manual        2        Renault
#
#                       model  modelYear  price     Insurance Validity  Seats  \
# 0            Maruti Celerio       2015   4.00  Third Party insurance    5.0
# 1             Ford Ecosport       2018   8.11          Comprehensive    5.0
# 2                Tata Tiago       2018   5.85          Comprehensive    5.0
# 3             Hyundai Xcent       2014   4.62          Comprehensive    5.0
# 4        Maruti SX4 S Cross       2015   7.90  Third Party insurance    5.0
# ...                     ...        ...    ...                    ...    ...
# 8364         Maruti Celerio       2022   5.10  Third Party insurance    5.0
# 8365        Maruti Alto 800       2014   1.80  Third Party insurance    5.0
# 8366  Mercedes-Benz C-Class       2011   5.50  Third Party insurance    5.0
# 8367            Maruti Ritz       2012   1.40  Third Party insurance    5.0
# 8368         Renault Duster       2017   5.00  Third Party insurance    5.0
#
#       Mileage  Engine   Color       City  Car Age      Car Size
# 0       23.10   998.0   White  Bangalore       10  9.505849e+09
# 1       17.00  1497.0   White  Bangalore        7  1.162201e+10
# 2       23.84  1199.0     Red  Bangalore        7  9.470431e+09
# 3       19.10  1197.0  Others  Bangalore       11  1.008018e+10
# 4       23.65  1248.0    Gray  Bangalore       10  1.224242e+10
# ...       ...     ...     ...        ...      ...           ...
# 8364    25.24   998.0  Others    Kolkata        3  9.509175e+09
# 8365    22.74   796.0  Others    Kolkata       11  7.461361e+09
# 8366    11.74  1796.0  Others    Kolkata       14  1.175842e+10
# 8367    18.50  1197.0  Others    Kolkata       13  1.027404e+10
# 8368    19.72  1461.0  Others    Kolkata        8  1.332597e+10
#
# [7046 rows x 17 columns]

# %% [markdown]
# # rename the columns

# %%
dff=dff.rename(columns={"ft":"Fuel Type","bt":"Body Type","transmission":"Transmission","ownerNo":"Owner No","model":"Model",
                        "modelYear":"Model Year","price":"Price","km":"Kilometer","oem":"Brand"})
dff
# Out:
#      Fuel Type  Body Type  Kilometer Transmission  Owner No          Brand  \
# 0       Petrol  Hatchback   120000.0       Manual         3         Maruti
# 1       Petrol        SUV    32706.0       Manual         2           Ford
# 2       Petrol  Hatchback    11949.0       Manual         1           Tata
# 3       Petrol      Sedan    17794.0       Manual         1        Hyundai
# 4       Diesel        SUV    60000.0       Manual         1         Maruti
# ...        ...        ...        ...          ...       ...            ...
# 8364    Petrol  Hatchback    10000.0       Manual         1         Maruti
# 8365    Petrol  Hatchback   120000.0       Manual         1         Maruti
# 8366    Petrol      Sedan    50000.0    Automatic         3  Mercedes-Benz
# 8367    Petrol  Hatchback    40000.0       Manual         1         Maruti
# 8368    Diesel        SUV   120000.0       Manual         2        Renault
#
#                       Model  Model Year  Price     Insurance Validity  Seats  \
# 0            Maruti Celerio        2015   4.00  Third Party insurance    5.0
# 1             Ford Ecosport        2018   8.11          Comprehensive    5.0
# 2                Tata Tiago        2018   5.85          Comprehensive    5.0
# 3             Hyundai Xcent        2014   4.62          Comprehensive    5.0
# 4        Maruti SX4 S Cross        2015   7.90  Third Party insurance    5.0
# ...                     ...         ...    ...                    ...    ...
# 8364         Maruti Celerio        2022   5.10  Third Party insurance    5.0
# 8365        Maruti Alto 800        2014   1.80  Third Party insurance    5.0
# 8366  Mercedes-Benz C-Class        2011   5.50  Third Party insurance    5.0
# 8367            Maruti Ritz        2012   1.40  Third Party insurance    5.0
# 8368         Renault Duster        2017   5.00  Third Party insurance    5.0
#
#       Mileage  Engine   Color       City  Car Age      Car Size
# 0       23.10   998.0   White  Bangalore       10  9.505849e+09
# 1       17.00  1497.0   White  Bangalore        7  1.162201e+10
# 2       23.84  1199.0     Red  Bangalore        7  9.470431e+09
# 3       19.10  1197.0  Others  Bangalore       11  1.008018e+10
# 4       23.65  1248.0    Gray  Bangalore       10  1.224242e+10
# ...       ...     ...     ...        ...      ...           ...
# 8364    25.24   998.0  Others    Kolkata        3  9.509175e+09
# 8365    22.74   796.0  Others    Kolkata       11  7.461361e+09
# 8366    11.74  1796.0  Others    Kolkata       14  1.175842e+10
# 8367    18.50  1197.0  Others    Kolkata       13  1.027404e+10
# 8368    19.72  1461.0  Others    Kolkata        8  1.332597e+10
#
# [7046 rows x 17 columns]

# %% [markdown]
# # label encoding for categorical features

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dff["Fuel Type"]=le.fit_transform(dff["Fuel Type"])
dff["Body Type"]=le.fit_transform(dff["Body Type"])
dff["Transmission"]=le.fit_transform(dff["Transmission"])
dff["Brand"]=le.fit_transform(dff["Brand"])
dff["Model"]=le.fit_transform(dff["Model"])
dff["Color"]=le.fit_transform(dff["Color"])
dff["Insurance Validity"]=le.fit_transform(dff["Insurance Validity"])
dff["City"]=le.fit_transform(dff["City"])
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7046 entries, 0 to 8368
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Fuel Type           7046 non-null   int64
#  1   Body Type           7046 non-null   int64
#  2   Kilometer           7046 non-null   float64
#  3   Transmission        7046 non-null   int64
#  4   Owner No            7046 non-null   int64
#  5   Brand               7046 non-null   int64
#  6   Model               7046 non-null   int64
#  7   Model Year          7046 non-null   int64
#  8   Price               7046 non-null   float64
#  9   Insurance Validity  7046 non-null   int64
#  10  Seats               7046 non-null   float64
#  11  Mileage             7046 non-null   float64
#  12  Engine              7046 non-null   float64
#  13  Color               7046 non-null   int64
#  14  City                7046 non-null   int64
#  15  Car Age             7046 non-null   int64
#  16  Car Size            7046 non-null   float64
# dtypes: float64(6), int64(11)
# memory usage: 990.8 KB

# %% [markdown]
# # split target and features

# %%
x=dff.drop("Price",axis=1)
y=dff["Price"]

# %%
x.shape,y.shape
# Out:
# ((7046, 16), (7046,))

# %% [markdown]
# # scale features

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
x_scaled=std.fit_transform(x)
x_scaled.shape
# Out:
# (7046, 16)

# %% [markdown]
# # split data by train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)
x_train.shape
# Out:
# (5636, 16)

# %%
x_test.shape
# Out:
# (1410, 16)

# %% [markdown]
# # model train

# %%
from sklearn.ensemble import RandomForestRegressor
model_rf=RandomForestRegressor(bootstrap=False, 
                               max_depth=20, 
                               max_features='sqrt',
                               min_samples_leaf=1,
                               min_samples_split=5, 
                               n_estimators=200)
model_rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=20, max_features='sqrt',
#                       min_samples_split=5, n_estimators=200)

# %% [markdown]
# # prediction

# %%
y_pred_rf=model_rf.predict(x_test)
y_pred_rf
# Out:
# array([2.98709167, 3.81432333, 4.14585192, ..., 8.24510461, 5.94918521,
#        5.37265209], shape=(1410,))

# %% [markdown]
# # evaluate test

# %%
print("mean squared error :",mean_squared_error(y_pred_rf,y_test))
print("Root mean squared error :",root_mean_squared_error(y_pred_rf,y_test))
print("mean absolute error :",mean_absolute_error(y_pred_rf,y_test))
print("r2 scored :",r2_score(y_pred_rf,y_test))
# Out:
# mean squared error : 1.1785073325313868
# Root mean squared error : 1.085590775813514
# mean absolute error : 0.7060578304777152
# r2 scored : 0.8744978885608371

# %% [markdown]
# # evaluate train

# %%
y_pred_train_rf=model_rf.predict(x_train)
y_pred_train_rf
# Out:
# array([5.56974583, 5.23925833, 9.13054542, ..., 5.0588352 , 4.85786167,
#        2.64653824], shape=(5636,))

# %%
print("mean squared error :",mean_squared_error(y_pred_train_rf,y_train))
print("Root mean squared error :",root_mean_squared_error(y_pred_train_rf,y_train))
print("mean absolute error :",mean_absolute_error(y_pred_train_rf,y_train))
print("r2 scored :",r2_score(y_pred_train_rf,y_train))
# Out:
# mean squared error : 0.10466167494249534
# Root mean squared error : 0.32351456681654284
# mean absolute error : 0.21774729273058485
# r2 scored : 0.9899908258569212

# %% [markdown]
# # save model as pickle

# %%
import pickle

# %%
pickle.dump(model_rf,open('final_model.pkl','wb'))
print("project saved successfully as a pickle file")
# Out:
# project saved successfully as a pickle file

# %% [markdown]
# # load and save pickled model

# %%
pickled_model=pickle.load(open('final_model.pkl','rb'))

# %% [markdown]
# # test training data

# %%
pickled_model.predict(x_test)
# Out:
# array([2.98709167, 3.81432333, 4.14585192, ..., 8.24510461, 5.94918521,
#        5.37265209], shape=(1410,))

# %%
df["Car Size"].min()
# Out:
# np.float64(6747372000.0)
